# %% [markdown]
# <a href="https://colab.research.google.com/github/MR-Munggaran/Prediksi-Cuaca/blob/main/Prediksi_Cuaca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
weather = pd.read_csv('laporan_iklim_harian_fixed.csv', index_col = "Tanggal")

output = weather.apply(pd.isnull).sum()/weather.shape[0]

print(output)
# Out:
# Tn         0.463504
# Tx         0.470803
# Tavg       0.500000
# RH_avg     0.500000
# RR         0.664234
# ss         0.609489
# ff_x       0.452555
# ddd_x      0.452555
# ff_avg     0.452555
# ddd_car    0.448905
# dtype: float64

# %%
core_weather = weather[["Tavg", "RH_avg","RR", "ss", "ff_avg"]].copy()

# %%
core_weather.columns = ["Temp_rata-rata", "Kelembapan_rata-rata","Curah_hujan","Lamanya_penyinaran_matahari","Kecepatan_angin_rata-rata"]

# %% [markdown]
# Keterangan :
#
#
# *   8888: data tidak terukur
# *   9999: Tidak Ada Data (tidak dilakukan pengukuran)
# *   Tn: Temperatur minimum	 (°C)
# *   Tx: Temperatur maksimum (°C)
# *   Tavg: Temperatur rata-rata (°C)
# *   RH_avg: Kelembapan rata-rata (%)
# *   RR: Curah hujan (mm)
# *   ss: Lamanya penyinaran matahari (jam)
# *   ff_x: Kecepatan angin maksimum (m/s)
# *   ddd_x: Arah angin saat kecepatan maksimum (°)
# *   ff_avg: Kecepatan angin rata-rata (m/s)
# *   ddd_car: Arah angin terbanyak (°)

# %%
core_weather
# Out:
#             Temp_rata-rata  Kelembapan_rata-rata  Curah_hujan  \
# Tanggal
# 01-01-2023             NaN                   NaN          NaN
# 02-01-2023             NaN                   NaN          NaN
# 03-01-2023             NaN                   NaN          NaN
# 04-01-2023            26.0                  92.0          4.1
# 05-01-2023            25.6                  90.0         18.6
# ...                    ...                   ...          ...
# 27-09-2023            29.4                  65.0          NaN
# 28-09-2023            29.7                  65.0          NaN
# 29-09-2023            30.3                  66.0          NaN
# 30-09-2023            29.0                  76.0          NaN
# 01-10-2023            29.1                  76.0          NaN
#
#             Lamanya_penyinaran_matahari  Kecepatan_angin_rata-rata
# Tanggal
# 01-01-2023                          NaN                        NaN
# 02-01-2023                          NaN                        NaN
# 03-01-2023                          NaN                        NaN
# 04-01-2023                          NaN                        2.0
# 05-01-2023                          NaN                        3.0
# ...                                 ...                        ...
# 27-09-2023                          9.2                        3.0
# 28-09-2023                         10.0                        3.0
# 29-09-2023                          9.9                        3.0
# 30-09-2023                         10.0                        2.0
# 01-10-2023                          9.6                        2.0
#
# [274 rows x 5 columns]

# %%
core_weather.apply(pd.isnull).sum()/core_weather.shape[0]
# Out:
# Temp_rata-rata                 0.500000
# Kelembapan_rata-rata           0.500000
# Curah_hujan                    0.664234
# Lamanya_penyinaran_matahari    0.609489
# Kecepatan_angin_rata-rata      0.452555
# dtype: float64

# %%
core_weather["Curah_hujan"].value_counts()
# Out:
# Curah_hujan
# 0.0       44
# 8888.0    11
# 0.8        2
# 1.7        2
# 0.4        2
# 4.1        1
# 49.0       1
# 13.0       1
# 7.5        1
# 63.0       1
# 7.3        1
# 3.7        1
# 7.4        1
# 12.5       1
# 8.7        1
# 33.9       1
# 72.0       1
# 6.7        1
# 28.9       1
# 17.5       1
# 0.7        1
# 5.2        1
# 9.3        1
# 18.6       1
# 16.8       1
# 25.5       1
# 0.5        1
# 4.5        1
# 30.5       1
# 6.0        1
# 7.0        1
# 11.7       1
# 35.1       1
# 15.2       1
# 10.0       1
# 1.5        1
# Name: count, dtype: int64

# %%
core_weather['Kecepatan_angin_rata-rata'].value_counts()
# Out:
# Kecepatan_angin_rata-rata
# 2.0    67
# 1.0    66
# 3.0    15
# 4.0     2
# Name: count, dtype: int64

# %%
core_weather['Kelembapan_rata-rata'].value_counts()
# Out:
# Kelembapan_rata-rata
# 76.0    15
# 74.0    13
# 75.0    11
# 78.0     9
# 80.0     9
# 79.0     8
# 83.0     7
# 84.0     7
# 77.0     7
# 86.0     5
# 85.0     5
# 81.0     4
# 89.0     4
# 82.0     4
# 88.0     4
# 71.0     3
# 90.0     3
# 91.0     3
# 66.0     2
# 64.0     2
# 72.0     2
# 65.0     2
# 87.0     2
# 97.0     1
# 94.0     1
# 69.0     1
# 73.0     1
# 70.0     1
# 92.0     1
# Name: count, dtype: int64

# %%
core_weather["Temp_rata-rata"].value_counts()
# Out:
# Temp_rata-rata
# 27.2    13
# 27.0     8
# 27.6     7
# 26.3     6
# 27.3     6
# 27.4     5
# 26.8     5
# 26.5     4
# 29.4     4
# 26.9     4
# 26.2     4
# 28.3     4
# 28.8     4
# 28.0     4
# 27.5     4
# 27.8     4
# 26.4     3
# 28.9     3
# 28.1     3
# 26.7     3
# 26.6     3
# 26.1     3
# 29.0     2
# 28.4     2
# 29.9     2
# 29.1     2
# 29.2     2
# 29.3     2
# 29.7     2
# 26.0     2
# 27.9     2
# 27.7     2
# 25.6     2
# 28.2     2
# 28.6     2
# 27.1     2
# 24.2     1
# 25.2     1
# 28.5     1
# 25.8     1
# 30.3     1
# Name: count, dtype: int64

# %%
core_weather[pd.isnull(core_weather["Temp_rata-rata"])]
# Out:
#             Temp_rata-rata  Kelembapan_rata-rata  Curah_hujan  \
# Tanggal
# 01-01-2023             NaN                   NaN          NaN
# 02-01-2023             NaN                   NaN          NaN
# 03-01-2023             NaN                   NaN          NaN
# 06-01-2023             NaN                   NaN          NaN
# 07-01-2023             NaN                   NaN          NaN
# ...                    ...                   ...          ...
# 16-08-2023             NaN                   NaN          NaN
# 17-08-2023             NaN                   NaN          NaN
# 18-08-2023             NaN                   NaN          NaN
# 20-08-2023             NaN                   NaN          NaN
# 23-08-2023             NaN                   NaN          NaN
#
#             Lamanya_penyinaran_matahari  Kecepatan_angin_rata-rata
# Tanggal
# 01-01-2023                          NaN                        NaN
# 02-01-2023                          NaN                        NaN
# 03-01-2023                          NaN                        NaN
# 06-01-2023                          NaN                        NaN
# 07-01-2023                          6.0                        NaN
# ...                                 ...                        ...
# 16-08-2023                          NaN                        NaN
# 17-08-2023                          NaN                        NaN
# 18-08-2023                          NaN                        NaN
# 20-08-2023                          NaN                        NaN
# 23-08-2023                          NaN                        NaN
#
# [137 rows x 5 columns]

# %%
core_weather["Temp_rata-rata"] = core_weather['Temp_rata-rata'].fillna(0)

# %%
core_weather[pd.isnull(core_weather["Temp_rata-rata"])]
# Out:
# Empty DataFrame
# Columns: [Temp_rata-rata, Kelembapan_rata-rata, Curah_hujan, Lamanya_penyinaran_matahari, Kecepatan_angin_rata-rata]
# Index: []

# %%
core_weather[pd.isnull(core_weather["Kelembapan_rata-rata"])]
# Out:
#             Temp_rata-rata  Kelembapan_rata-rata  Curah_hujan  \
# Tanggal
# 01-01-2023             0.0                   NaN          NaN
# 02-01-2023             0.0                   NaN          NaN
# 03-01-2023             0.0                   NaN          NaN
# 06-01-2023             0.0                   NaN          NaN
# 07-01-2023             0.0                   NaN          NaN
# ...                    ...                   ...          ...
# 16-08-2023             0.0                   NaN          NaN
# 17-08-2023             0.0                   NaN          NaN
# 18-08-2023             0.0                   NaN          NaN
# 20-08-2023             0.0                   NaN          NaN
# 23-08-2023             0.0                   NaN          NaN
#
#             Lamanya_penyinaran_matahari  Kecepatan_angin_rata-rata
# Tanggal
# 01-01-2023                          NaN                        NaN
# 02-01-2023                          NaN                        NaN
# 03-01-2023                          NaN                        NaN
# 06-01-2023                          NaN                        NaN
# 07-01-2023                          6.0                        NaN
# ...                                 ...                        ...
# 16-08-2023                          NaN                        NaN
# 17-08-2023                          NaN                        NaN
# 18-08-2023                          NaN                        NaN
# 20-08-2023                          NaN                        NaN
# 23-08-2023                          NaN                        NaN
#
# [137 rows x 5 columns]

# %%
core_weather["Kelembapan_rata-rata"] = core_weather['Kelembapan_rata-rata'].fillna(0)

# %%
core_weather[pd.isnull(core_weather["Kelembapan_rata-rata"])]
# Out:
# Empty DataFrame
# Columns: [Temp_rata-rata, Kelembapan_rata-rata, Curah_hujan, Lamanya_penyinaran_matahari, Kecepatan_angin_rata-rata]
# Index: []

# %%
core_weather[pd.isnull(core_weather["Curah_hujan"])]
# Out:
#             Temp_rata-rata  Kelembapan_rata-rata  Curah_hujan  \
# Tanggal
# 01-01-2023             0.0                   0.0          NaN
# 02-01-2023             0.0                   0.0          NaN
# 03-01-2023             0.0                   0.0          NaN
# 06-01-2023             0.0                   0.0          NaN
# 07-01-2023             0.0                   0.0          NaN
# ...                    ...                   ...          ...
# 27-09-2023            29.4                  65.0          NaN
# 28-09-2023            29.7                  65.0          NaN
# 29-09-2023            30.3                  66.0          NaN
# 30-09-2023            29.0                  76.0          NaN
# 01-10-2023            29.1                  76.0          NaN
#
#             Lamanya_penyinaran_matahari  Kecepatan_angin_rata-rata
# Tanggal
# 01-01-2023                          NaN                        NaN
# 02-01-2023                          NaN                        NaN
# 03-01-2023                          NaN                        NaN
# 06-01-2023                          NaN                        NaN
# 07-01-2023                          6.0                        NaN
# ...                                 ...                        ...
# 27-09-2023                          9.2                        3.0
# 28-09-2023                         10.0                        3.0
# 29-09-2023                          9.9                        3.0
# 30-09-2023                         10.0                        2.0
# 01-10-2023                          9.6                        2.0
#
# [182 rows x 5 columns]

# %%
core_weather["Curah_hujan"] = core_weather['Curah_hujan'].fillna(0)

# %%
core_weather[pd.isnull(core_weather["Curah_hujan"])]
# Out:
# Empty DataFrame
# Columns: [Temp_rata-rata, Kelembapan_rata-rata, Curah_hujan, Lamanya_penyinaran_matahari, Kecepatan_angin_rata-rata]
# Index: []

# %%
core_weather[pd.isnull(core_weather["Lamanya_penyinaran_matahari"])]
# Out:
#             Temp_rata-rata  Kelembapan_rata-rata  Curah_hujan  \
# Tanggal
# 01-01-2023             0.0                   0.0          0.0
# 02-01-2023             0.0                   0.0          0.0
# 03-01-2023             0.0                   0.0          0.0
# 04-01-2023            26.0                  92.0          4.1
# 05-01-2023            25.6                  90.0         18.6
# ...                    ...                   ...          ...
# 17-08-2023             0.0                   0.0          0.0
# 18-08-2023             0.0                   0.0          0.0
# 20-08-2023             0.0                   0.0          0.0
# 23-08-2023             0.0                   0.0          0.0
# 01-09-2023            26.7                  74.0          0.0
#
#             Lamanya_penyinaran_matahari  Kecepatan_angin_rata-rata
# Tanggal
# 01-01-2023                          NaN                        NaN
# 02-01-2023                          NaN                        NaN
# 03-01-2023                          NaN                        NaN
# 04-01-2023                          NaN                        2.0
# 05-01-2023                          NaN                        3.0
# ...                                 ...                        ...
# 17-08-2023                          NaN                        NaN
# 18-08-2023                          NaN                        NaN
# 20-08-2023                          NaN                        NaN
# 23-08-2023                          NaN                        NaN
# 01-09-2023                          NaN                        2.0
#
# [167 rows x 5 columns]

# %%
core_weather["Lamanya_penyinaran_matahari"] = core_weather['Lamanya_penyinaran_matahari'].fillna(0)

# %%
core_weather[pd.isnull(core_weather["Lamanya_penyinaran_matahari"])]
# Out:
# Empty DataFrame
# Columns: [Temp_rata-rata, Kelembapan_rata-rata, Curah_hujan, Lamanya_penyinaran_matahari, Kecepatan_angin_rata-rata]
# Index: []

# %%
core_weather[pd.isnull(core_weather["Kecepatan_angin_rata-rata"])]
# Out:
#             Temp_rata-rata  Kelembapan_rata-rata  Curah_hujan  \
# Tanggal
# 01-01-2023             0.0                   0.0          0.0
# 02-01-2023             0.0                   0.0          0.0
# 03-01-2023             0.0                   0.0          0.0
# 06-01-2023             0.0                   0.0          0.0
# 07-01-2023             0.0                   0.0          0.0
# ...                    ...                   ...          ...
# 16-08-2023             0.0                   0.0          0.0
# 17-08-2023             0.0                   0.0          0.0
# 18-08-2023             0.0                   0.0          0.0
# 20-08-2023             0.0                   0.0          0.0
# 23-08-2023             0.0                   0.0          0.0
#
#             Lamanya_penyinaran_matahari  Kecepatan_angin_rata-rata
# Tanggal
# 01-01-2023                          0.0                        NaN
# 02-01-2023                          0.0                        NaN
# 03-01-2023                          0.0                        NaN
# 06-01-2023                          0.0                        NaN
# 07-01-2023                          6.0                        NaN
# ...                                 ...                        ...
# 16-08-2023                          0.0                        NaN
# 17-08-2023                          0.0                        NaN
# 18-08-2023                          0.0                        NaN
# 20-08-2023                          0.0                        NaN
# 23-08-2023                          0.0                        NaN
#
# [124 rows x 5 columns]

# %%
core_weather["Kecepatan_angin_rata-rata"] = core_weather['Kecepatan_angin_rata-rata'].fillna(0)

# %%
core_weather[pd.isnull(core_weather["Kecepatan_angin_rata-rata"])]
# Out:
# Empty DataFrame
# Columns: [Temp_rata-rata, Kelembapan_rata-rata, Curah_hujan, Lamanya_penyinaran_matahari, Kecepatan_angin_rata-rata]
# Index: []

# %%
core_weather
# Out:
#             Temp_rata-rata  Kelembapan_rata-rata  Curah_hujan  \
# Tanggal
# 01-01-2023             0.0                   0.0          0.0
# 02-01-2023             0.0                   0.0          0.0
# 03-01-2023             0.0                   0.0          0.0
# 04-01-2023            26.0                  92.0          4.1
# 05-01-2023            25.6                  90.0         18.6
# ...                    ...                   ...          ...
# 27-09-2023            29.4                  65.0          0.0
# 28-09-2023            29.7                  65.0          0.0
# 29-09-2023            30.3                  66.0          0.0
# 30-09-2023            29.0                  76.0          0.0
# 01-10-2023            29.1                  76.0          0.0
#
#             Lamanya_penyinaran_matahari  Kecepatan_angin_rata-rata
# Tanggal
# 01-01-2023                          0.0                        0.0
# 02-01-2023                          0.0                        0.0
# 03-01-2023                          0.0                        0.0
# 04-01-2023                          0.0                        2.0
# 05-01-2023                          0.0                        3.0
# ...                                 ...                        ...
# 27-09-2023                          9.2                        3.0
# 28-09-2023                         10.0                        3.0
# 29-09-2023                          9.9                        3.0
# 30-09-2023                         10.0                        2.0
# 01-10-2023                          9.6                        2.0
#
# [274 rows x 5 columns]

# %%
for x in core_weather.index:
  if core_weather.loc[x, "Temp_rata-rata"] == 0.0:
    core_weather.drop(x, inplace=True)

# %%
for x in core_weather.index:
  if core_weather.loc[x, "Curah_hujan"] == 0.0:
    core_weather.drop(x, inplace=True)

# %%
for x in core_weather.index:
  if core_weather.loc[x, "Lamanya_penyinaran_matahari"] == 0.0:
    core_weather.drop(x, inplace=True)

# %%
for x in core_weather.index:
  if core_weather.loc[x, "Kecepatan_angin_rata-rata"] == 0.0:
    core_weather.drop(x, inplace=True)

# %%
core_weather
# Out:
#             Temp_rata-rata  Kelembapan_rata-rata  Curah_hujan  \
# Tanggal
# 28-02-2023            26.1                  89.0          1.7
# 02-04-2023            27.4                  86.0         11.7
# 13-04-2023            27.6                  80.0          7.0
# 27-04-2023            27.2                  85.0          6.0
# 28-04-2023            26.5                  94.0         30.5
# 10-05-2023            28.8                  84.0          0.5
# 13-05-2023            27.6                  87.0          0.4
# 14-05-2023            27.3                  77.0         25.5
# 06-06-2023            26.3                  91.0         12.5
# 07-06-2023            26.3                  83.0         17.5
# 08-06-2023            27.9                  82.0         13.0
# 13-06-2023            26.2                  85.0          7.5
# 14-06-2023            25.2                  89.0         63.0
# 16-06-2023            24.2                  97.0         49.0
# 19-06-2023            26.3                  89.0          3.7
# 22-06-2023            28.3                  80.0          8.7
# 26-06-2023            26.4                  85.0       8888.0
# 28-06-2023            27.2                  80.0         33.9
# 25-07-2023            26.8                  81.0       8888.0
# 29-08-2023            26.7                  76.0       8888.0
# 18-09-2023            29.9                  76.0       8888.0
# 20-09-2023            28.8                  78.0         28.9
# 22-09-2023            28.9                  76.0          1.5
#
#             Lamanya_penyinaran_matahari  Kecepatan_angin_rata-rata
# Tanggal
# 28-02-2023                          0.6                        3.0
# 02-04-2023                          0.6                        2.0
# 13-04-2023                          5.9                        4.0
# 27-04-2023                          3.5                        1.0
# 28-04-2023                          2.7                        1.0
# 10-05-2023                          3.9                        2.0
# 13-05-2023                          4.5                        2.0
# 14-05-2023                          4.0                        1.0
# 06-06-2023                          2.8                        2.0
# 07-06-2023                          0.5                        1.0
# 08-06-2023                          1.6                        2.0
# 13-06-2023                          0.1                        2.0
# 14-06-2023                          1.0                        2.0
# 16-06-2023                          5.1                        1.0
# 19-06-2023                          0.8                        2.0
# 22-06-2023                          4.0                        1.0
# 26-06-2023                          2.6                        1.0
# 28-06-2023                          5.5                        2.0
# 25-07-2023                          3.5                        1.0
# 29-08-2023                          1.0                        1.0
# 18-09-2023                          6.0                        2.0
# 20-09-2023                          0.9                        2.0
# 22-09-2023                          7.5                        2.0

# %%
core_weather.dtypes
# Out:
# Temp_rata-rata                 float64
# Kelembapan_rata-rata           float64
# Curah_hujan                    float64
# Lamanya_penyinaran_matahari    float64
# Kecepatan_angin_rata-rata      float64
# dtype: object

# %%
core_weather.index
# Out:
# Index(['28-02-2023', '02-04-2023', '13-04-2023', '27-04-2023', '28-04-2023',
#        '10-05-2023', '13-05-2023', '14-05-2023', '06-06-2023', '07-06-2023',
#        '08-06-2023', '13-06-2023', '14-06-2023', '16-06-2023', '19-06-2023',
#        '22-06-2023', '26-06-2023', '28-06-2023', '25-07-2023', '29-08-2023',
#        '18-09-2023', '20-09-2023', '22-09-2023'],
#       dtype='object', name='Tanggal')

# %%
core_weather.index = pd.to_datetime(core_weather.index)
# Out:
# C:\Users\Xilia\AppData\Local\Temp\ipykernel_18000\3501870966.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   core_weather.index = pd.to_datetime(core_weather.index)

# %%
core_weather.index
# Out:
# DatetimeIndex(['2023-02-28', '2023-04-02', '2023-04-13', '2023-04-27',
#                '2023-04-28', '2023-05-10', '2023-05-13', '2023-05-14',
#                '2023-06-06', '2023-06-07', '2023-06-08', '2023-06-13',
#                '2023-06-14', '2023-06-16', '2023-06-19', '2023-06-22',
#                '2023-06-26', '2023-06-28', '2023-07-25', '2023-08-29',
#                '2023-09-18', '2023-09-20', '2023-09-22'],
#               dtype='datetime64[ns]', name='Tanggal', freq=None)

# %%
core_weather.apply(lambda x:(x==8888).sum())
# Out:
# Temp_rata-rata                 0
# Kelembapan_rata-rata           0
# Curah_hujan                    4
# Lamanya_penyinaran_matahari    0
# Kecepatan_angin_rata-rata      0
# dtype: int64

# %%
core_weather.dtypes
# Out:
# Temp_rata-rata                 float64
# Kelembapan_rata-rata           float64
# Curah_hujan                    float64
# Lamanya_penyinaran_matahari    float64
# Kecepatan_angin_rata-rata      float64
# dtype: object

# %%
core_weather
# Out:
#             Temp_rata-rata  Kelembapan_rata-rata  Curah_hujan  \
# Tanggal
# 2023-02-28            26.1                  89.0          1.7
# 2023-04-02            27.4                  86.0         11.7
# 2023-04-13            27.6                  80.0          7.0
# 2023-04-27            27.2                  85.0          6.0
# 2023-04-28            26.5                  94.0         30.5
# 2023-05-10            28.8                  84.0          0.5
# 2023-05-13            27.6                  87.0          0.4
# 2023-05-14            27.3                  77.0         25.5
# 2023-06-06            26.3                  91.0         12.5
# 2023-06-07            26.3                  83.0         17.5
# 2023-06-08            27.9                  82.0         13.0
# 2023-06-13            26.2                  85.0          7.5
# 2023-06-14            25.2                  89.0         63.0
# 2023-06-16            24.2                  97.0         49.0
# 2023-06-19            26.3                  89.0          3.7
# 2023-06-22            28.3                  80.0          8.7
# 2023-06-26            26.4                  85.0       8888.0
# 2023-06-28            27.2                  80.0         33.9
# 2023-07-25            26.8                  81.0       8888.0
# 2023-08-29            26.7                  76.0       8888.0
# 2023-09-18            29.9                  76.0       8888.0
# 2023-09-20            28.8                  78.0         28.9
# 2023-09-22            28.9                  76.0          1.5
#
#             Lamanya_penyinaran_matahari  Kecepatan_angin_rata-rata
# Tanggal
# 2023-02-28                          0.6                        3.0
# 2023-04-02                          0.6                        2.0
# 2023-04-13                          5.9                        4.0
# 2023-04-27                          3.5                        1.0
# 2023-04-28                          2.7                        1.0
# 2023-05-10                          3.9                        2.0
# 2023-05-13                          4.5                        2.0
# 2023-05-14                          4.0                        1.0
# 2023-06-06                          2.8                        2.0
# 2023-06-07                          0.5                        1.0
# 2023-06-08                          1.6                        2.0
# 2023-06-13                          0.1                        2.0
# 2023-06-14                          1.0                        2.0
# 2023-06-16                          5.1                        1.0
# 2023-06-19                          0.8                        2.0
# 2023-06-22                          4.0                        1.0
# 2023-06-26                          2.6                        1.0
# 2023-06-28                          5.5                        2.0
# 2023-07-25                          3.5                        1.0
# 2023-08-29                          1.0                        1.0
# 2023-09-18                          6.0                        2.0
# 2023-09-20                          0.9                        2.0
# 2023-09-22                          7.5                        2.0

# %%
for x in core_weather.index:
  if core_weather.loc[x, "Curah_hujan"] == 8888.0:
    core_weather.drop(x, inplace=True)

# %%
core_weather
# Out:
#             Temp_rata-rata  Kelembapan_rata-rata  Curah_hujan  \
# Tanggal
# 2023-02-28            26.1                  89.0          1.7
# 2023-04-02            27.4                  86.0         11.7
# 2023-04-13            27.6                  80.0          7.0
# 2023-04-27            27.2                  85.0          6.0
# 2023-04-28            26.5                  94.0         30.5
# 2023-05-10            28.8                  84.0          0.5
# 2023-05-13            27.6                  87.0          0.4
# 2023-05-14            27.3                  77.0         25.5
# 2023-06-06            26.3                  91.0         12.5
# 2023-06-07            26.3                  83.0         17.5
# 2023-06-08            27.9                  82.0         13.0
# 2023-06-13            26.2                  85.0          7.5
# 2023-06-14            25.2                  89.0         63.0
# 2023-06-16            24.2                  97.0         49.0
# 2023-06-19            26.3                  89.0          3.7
# 2023-06-22            28.3                  80.0          8.7
# 2023-06-28            27.2                  80.0         33.9
# 2023-09-20            28.8                  78.0         28.9
# 2023-09-22            28.9                  76.0          1.5
#
#             Lamanya_penyinaran_matahari  Kecepatan_angin_rata-rata
# Tanggal
# 2023-02-28                          0.6                        3.0
# 2023-04-02                          0.6                        2.0
# 2023-04-13                          5.9                        4.0
# 2023-04-27                          3.5                        1.0
# 2023-04-28                          2.7                        1.0
# 2023-05-10                          3.9                        2.0
# 2023-05-13                          4.5                        2.0
# 2023-05-14                          4.0                        1.0
# 2023-06-06                          2.8                        2.0
# 2023-06-07                          0.5                        1.0
# 2023-06-08                          1.6                        2.0
# 2023-06-13                          0.1                        2.0
# 2023-06-14                          1.0                        2.0
# 2023-06-16                          5.1                        1.0
# 2023-06-19                          0.8                        2.0
# 2023-06-22                          4.0                        1.0
# 2023-06-28                          5.5                        2.0
# 2023-09-20                          0.9                        2.0
# 2023-09-22                          7.5                        2.0

# %%
core_weather.to_csv("Data_fixed.csv")
