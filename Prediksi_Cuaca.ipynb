# %% [markdown]
# <a href="https://colab.research.google.com/github/MR-Munggaran/Prediksi-Cuaca/blob/main/Prediksi_Cuaca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
weather = pd.read_csv('laporan_iklim_harian_fixed.csv', index_col = "Tanggal")

output = weather.apply(pd.isnull).sum()/weather.shape[0]

print(output)
# Out:
# Tn         0.463504
# Tx         0.470803
# Tavg       0.500000
# RH_avg     0.500000
# RR         0.664234
# ss         0.609489
# ff_x       0.452555
# ddd_x      0.452555
# ff_avg     0.452555
# ddd_car    0.448905
# dtype: float64

# %%
core_weather = weather[["Tavg", "RH_avg","RR", "ss", "ff_avg"]].copy()

# %%
core_weather.columns = ["Temp_rata-rata", "Kelembapan_rata-rata","Curah_hujan","Lamanya_penyinaran_matahari","Kecepatan_angin_rata-rata"]

# %% [markdown]
# Keterangan :
#
#
# *   8888: data tidak terukur
# *   9999: Tidak Ada Data (tidak dilakukan pengukuran)
# *   Tn: Temperatur minimum	 (°C)
# *   Tx: Temperatur maksimum (°C)
# *   Tavg: Temperatur rata-rata (°C)
# *   RH_avg: Kelembapan rata-rata (%)
# *   RR: Curah hujan (mm)
# *   ss: Lamanya penyinaran matahari (jam)
# *   ff_x: Kecepatan angin maksimum (m/s)
# *   ddd_x: Arah angin saat kecepatan maksimum (°)
# *   ff_avg: Kecepatan angin rata-rata (m/s)
# *   ddd_car: Arah angin terbanyak (°)

# %%
core_weather
# Out:
#             Temp_rata-rata  Kelembapan_rata-rata  Curah_hujan  \
# Tanggal
# 2023-01-01             0.0                   0.0          NaN
# 2023-02-01             0.0                   0.0          NaN
# 2023-03-01             0.0                   0.0          NaN
# 2023-04-01            92.0                  92.0          4.1
# 2023-05-01            90.0                  90.0         18.6
# ...                    ...                   ...          ...
# 2023-09-27            65.0                  65.0          NaN
# 2023-09-28            65.0                  65.0          NaN
# 2023-09-29            66.0                  66.0          NaN
# 2023-09-30            76.0                  76.0          NaN
# 2023-01-10            76.0                  76.0          NaN
#
#             Lamanya_penyinaran_matahari  Kecepatan_angin_rata-rata
# Tanggal
# 2023-01-01                          NaN                        NaN
# 2023-02-01                          NaN                        NaN
# 2023-03-01                          NaN                        NaN
# 2023-04-01                          NaN                        2.0
# 2023-05-01                          NaN                        3.0
# ...                                 ...                        ...
# 2023-09-27                          9.2                        3.0
# 2023-09-28                         10.0                        3.0
# 2023-09-29                          9.9                        3.0
# 2023-09-30                         10.0                        2.0
# 2023-01-10                          9.6                        2.0
#
# [274 rows x 5 columns]

# %%
core_weather.apply(pd.isnull).sum()/core_weather.shape[0]
# Out:
# Temp_rata-rata                 0.500000
# Kelembapan_rata-rata           0.500000
# Curah_hujan                    0.664234
# Lamanya_penyinaran_matahari    0.609489
# Kecepatan_angin_rata-rata      0.452555
# dtype: float64

# %%
core_weather["Curah_hujan"].value_counts()
# Out:
# 0.0       44
# 8888.0    11
# 0.8        2
# 1.7        2
# 0.4        2
# 4.1        1
# 49.0       1
# 13.0       1
# 7.5        1
# 63.0       1
# 7.3        1
# 3.7        1
# 7.4        1
# 12.5       1
# 8.7        1
# 33.9       1
# 72.0       1
# 6.7        1
# 28.9       1
# 17.5       1
# 0.7        1
# 5.2        1
# 9.3        1
# 18.6       1
# 16.8       1
# 25.5       1
# 0.5        1
# 4.5        1
# 30.5       1
# 6.0        1
# 7.0        1
# 11.7       1
# 35.1       1
# 15.2       1
# 10.0       1
# 1.5        1
# Name: Curah_hujan, dtype: int64

# %%
core_weather['Kecepatan_angin_rata-rata'].value_counts()
# Out:
# 2.0    67
# 1.0    66
# 3.0    15
# 4.0     2
# Name: Kecepatan_angin_rata-rata, dtype: int64

# %%
core_weather['Kelembapan_rata-rata'].value_counts()
# Out:
# 76.0    15
# 74.0    13
# 75.0    11
# 78.0     9
# 80.0     9
# 79.0     8
# 83.0     7
# 84.0     7
# 77.0     7
# 86.0     5
# 85.0     5
# 81.0     4
# 89.0     4
# 82.0     4
# 88.0     4
# 71.0     3
# 90.0     3
# 91.0     3
# 66.0     2
# 64.0     2
# 72.0     2
# 65.0     2
# 87.0     2
# 97.0     1
# 94.0     1
# 69.0     1
# 73.0     1
# 70.0     1
# 92.0     1
# Name: Kelembapan_rata-rata, dtype: int64

# %%
del core_weather["Curah_hujan"]

# %%
core_weather["Temp_rata-rata"].value_counts()
# Out:
# 27.2    13
# 27.0     8
# 27.6     7
# 26.3     6
# 27.3     6
# 27.4     5
# 26.8     5
# 26.5     4
# 29.4     4
# 26.9     4
# 26.2     4
# 28.3     4
# 28.8     4
# 28.0     4
# 27.5     4
# 27.8     4
# 26.4     3
# 28.9     3
# 28.1     3
# 26.7     3
# 26.6     3
# 26.1     3
# 29.0     2
# 28.4     2
# 29.9     2
# 29.1     2
# 29.2     2
# 29.3     2
# 29.7     2
# 26.0     2
# 27.9     2
# 27.7     2
# 25.6     2
# 28.2     2
# 28.6     2
# 27.1     2
# 24.2     1
# 25.2     1
# 28.5     1
# 25.8     1
# 30.3     1
# Name: Temp_rata-rata, dtype: int64

# %%
core_weather[pd.isnull(core_weather["Temp_rata-rata"])]
# Out:
#             Temp_rata-rata  Kelembapan_rata-rata  Curah_hujan  \
# Tanggal
# 2023-01-01             NaN                   NaN          NaN
# 2023-02-01             NaN                   NaN          NaN
# 2023-03-01             NaN                   NaN          NaN
# 2023-06-01             NaN                   NaN          NaN
# 2023-07-01             NaN                   NaN          NaN
# ...                    ...                   ...          ...
# 2023-08-16             NaN                   NaN          NaN
# 2023-08-17             NaN                   NaN          NaN
# 2023-08-18             NaN                   NaN          NaN
# 2023-08-20             NaN                   NaN          NaN
# 2023-08-23             NaN                   NaN          NaN
#
#             Lamanya_penyinaran_matahari  Kecepatan_angin_rata-rata
# Tanggal
# 2023-01-01                          NaN                        NaN
# 2023-02-01                          NaN                        NaN
# 2023-03-01                          NaN                        NaN
# 2023-06-01                          NaN                        NaN
# 2023-07-01                          6.0                        NaN
# ...                                 ...                        ...
# 2023-08-16                          NaN                        NaN
# 2023-08-17                          NaN                        NaN
# 2023-08-18                          NaN                        NaN
# 2023-08-20                          NaN                        NaN
# 2023-08-23                          NaN                        NaN
#
# [137 rows x 5 columns]

# %%
core_weather["Temp_rata-rata"] = core_weather['Temp_rata-rata'].fillna(0)

# %%
core_weather[pd.isnull(core_weather["Temp_rata-rata"])]
# Out:
# Empty DataFrame
# Columns: [Temp_rata-rata, Kelembapan_rata-rata, Curah_hujan, Lamanya_penyinaran_matahari, Kecepatan_angin_rata-rata]
# Index: []

# %%
core_weather[pd.isnull(core_weather["Kelembapan_rata-rata"])]
# Out:
#             Temp_rata-rata  Kelembapan_rata-rata  Curah_hujan  \
# Tanggal
# 2023-01-01             0.0                   NaN          NaN
# 2023-02-01             0.0                   NaN          NaN
# 2023-03-01             0.0                   NaN          NaN
# 2023-06-01             0.0                   NaN          NaN
# 2023-07-01             0.0                   NaN          NaN
# ...                    ...                   ...          ...
# 2023-08-16             0.0                   NaN          NaN
# 2023-08-17             0.0                   NaN          NaN
# 2023-08-18             0.0                   NaN          NaN
# 2023-08-20             0.0                   NaN          NaN
# 2023-08-23             0.0                   NaN          NaN
#
#             Lamanya_penyinaran_matahari  Kecepatan_angin_rata-rata
# Tanggal
# 2023-01-01                          NaN                        NaN
# 2023-02-01                          NaN                        NaN
# 2023-03-01                          NaN                        NaN
# 2023-06-01                          NaN                        NaN
# 2023-07-01                          6.0                        NaN
# ...                                 ...                        ...
# 2023-08-16                          NaN                        NaN
# 2023-08-17                          NaN                        NaN
# 2023-08-18                          NaN                        NaN
# 2023-08-20                          NaN                        NaN
# 2023-08-23                          NaN                        NaN
#
# [137 rows x 5 columns]

# %%
core_weather["Kelembapan_rata-rata"] = core_weather['Kelembapan_rata-rata'].fillna(0)

# %%
core_weather[pd.isnull(core_weather["Kelembapan_rata-rata"])]
# Out:
# Empty DataFrame
# Columns: [Temp_rata-rata, Kelembapan_rata-rata, Curah_hujan, Lamanya_penyinaran_matahari, Kecepatan_angin_rata-rata]
# Index: []

# %%
core_weather[pd.isnull(core_weather["Curah_hujan"])]
# Out:
#             Temp_rata-rata  Kelembapan_rata-rata  Curah_hujan  \
# Tanggal
# 2023-01-01             0.0                   0.0          NaN
# 2023-02-01             0.0                   0.0          NaN
# 2023-03-01             0.0                   0.0          NaN
# 2023-06-01             0.0                   0.0          NaN
# 2023-07-01             0.0                   0.0          NaN
# ...                    ...                   ...          ...
# 2023-09-27            65.0                  65.0          NaN
# 2023-09-28            65.0                  65.0          NaN
# 2023-09-29            66.0                  66.0          NaN
# 2023-09-30            76.0                  76.0          NaN
# 2023-01-10            76.0                  76.0          NaN
#
#             Lamanya_penyinaran_matahari  Kecepatan_angin_rata-rata
# Tanggal
# 2023-01-01                          NaN                        NaN
# 2023-02-01                          NaN                        NaN
# 2023-03-01                          NaN                        NaN
# 2023-06-01                          NaN                        NaN
# 2023-07-01                          6.0                        NaN
# ...                                 ...                        ...
# 2023-09-27                          9.2                        3.0
# 2023-09-28                         10.0                        3.0
# 2023-09-29                          9.9                        3.0
# 2023-09-30                         10.0                        2.0
# 2023-01-10                          9.6                        2.0
#
# [182 rows x 5 columns]

# %%
core_weather["Curah_hujan"] = core_weather['Curah_hujan'].fillna(0)

# %%
core_weather[pd.isnull(core_weather["Curah_hujan"])]
# Out:
# Empty DataFrame
# Columns: [Temp_rata-rata, Kelembapan_rata-rata, Curah_hujan, Lamanya_penyinaran_matahari, Kecepatan_angin_rata-rata]
# Index: []

# %%
core_weather[pd.isnull(core_weather["Lamanya_penyinaran_matahari"])]
# Out:
#             Temp_rata-rata  Kelembapan_rata-rata  Curah_hujan  \
# Tanggal
# 2023-01-01             0.0                   0.0          0.0
# 2023-02-01             0.0                   0.0          0.0
# 2023-03-01             0.0                   0.0          0.0
# 2023-04-01            92.0                  92.0          4.1
# 2023-05-01            90.0                  90.0         18.6
# ...                    ...                   ...          ...
# 2023-08-17             0.0                   0.0          0.0
# 2023-08-18             0.0                   0.0          0.0
# 2023-08-20             0.0                   0.0          0.0
# 2023-08-23             0.0                   0.0          0.0
# 2023-01-09            74.0                  74.0          0.0
#
#             Lamanya_penyinaran_matahari  Kecepatan_angin_rata-rata
# Tanggal
# 2023-01-01                          NaN                        NaN
# 2023-02-01                          NaN                        NaN
# 2023-03-01                          NaN                        NaN
# 2023-04-01                          NaN                        2.0
# 2023-05-01                          NaN                        3.0
# ...                                 ...                        ...
# 2023-08-17                          NaN                        NaN
# 2023-08-18                          NaN                        NaN
# 2023-08-20                          NaN                        NaN
# 2023-08-23                          NaN                        NaN
# 2023-01-09                          NaN                        2.0
#
# [167 rows x 5 columns]

# %%
core_weather["Lamanya_penyinaran_matahari"] = core_weather['Lamanya_penyinaran_matahari'].fillna(0)

# %%
core_weather[pd.isnull(core_weather["Lamanya_penyinaran_matahari"])]
# Out:
# Empty DataFrame
# Columns: [Temp_rata-rata, Kelembapan_rata-rata, Curah_hujan, Lamanya_penyinaran_matahari, Kecepatan_angin_rata-rata]
# Index: []

# %%
core_weather[pd.isnull(core_weather["Kecepatan_angin_rata-rata"])]
# Out:
#             Temp_rata-rata  Kelembapan_rata-rata  Curah_hujan  \
# Tanggal
# 2023-01-01             0.0                   0.0          0.0
# 2023-02-01             0.0                   0.0          0.0
# 2023-03-01             0.0                   0.0          0.0
# 2023-06-01             0.0                   0.0          0.0
# 2023-07-01             0.0                   0.0          0.0
# ...                    ...                   ...          ...
# 2023-08-16             0.0                   0.0          0.0
# 2023-08-17             0.0                   0.0          0.0
# 2023-08-18             0.0                   0.0          0.0
# 2023-08-20             0.0                   0.0          0.0
# 2023-08-23             0.0                   0.0          0.0
#
#             Lamanya_penyinaran_matahari  Kecepatan_angin_rata-rata
# Tanggal
# 2023-01-01                          0.0                        NaN
# 2023-02-01                          0.0                        NaN
# 2023-03-01                          0.0                        NaN
# 2023-06-01                          0.0                        NaN
# 2023-07-01                          6.0                        NaN
# ...                                 ...                        ...
# 2023-08-16                          0.0                        NaN
# 2023-08-17                          0.0                        NaN
# 2023-08-18                          0.0                        NaN
# 2023-08-20                          0.0                        NaN
# 2023-08-23                          0.0                        NaN
#
# [124 rows x 5 columns]

# %%
core_weather["Kecepatan_angin_rata-rata"] = core_weather['Kecepatan_angin_rata-rata'].fillna(0)

# %%
core_weather[pd.isnull(core_weather["Kecepatan_angin_rata-rata"])]
# Out:
# Empty DataFrame
# Columns: [Temp_rata-rata, Kelembapan_rata-rata, Curah_hujan, Lamanya_penyinaran_matahari, Kecepatan_angin_rata-rata]
# Index: []

# %%
core_weather
# Out:
#             Temp_rata-rata  Kelembapan_rata-rata  Curah_hujan  \
# Tanggal
# 2023-01-01             0.0                   0.0          0.0
# 2023-02-01             0.0                   0.0          0.0
# 2023-03-01             0.0                   0.0          0.0
# 2023-04-01            92.0                  92.0          4.1
# 2023-05-01            90.0                  90.0         18.6
# ...                    ...                   ...          ...
# 2023-09-27            65.0                  65.0          0.0
# 2023-09-28            65.0                  65.0          0.0
# 2023-09-29            66.0                  66.0          0.0
# 2023-09-30            76.0                  76.0          0.0
# 2023-01-10            76.0                  76.0          0.0
#
#             Lamanya_penyinaran_matahari  Kecepatan_angin_rata-rata
# Tanggal
# 2023-01-01                          0.0                        0.0
# 2023-02-01                          0.0                        0.0
# 2023-03-01                          0.0                        0.0
# 2023-04-01                          0.0                        2.0
# 2023-05-01                          0.0                        3.0
# ...                                 ...                        ...
# 2023-09-27                          9.2                        3.0
# 2023-09-28                         10.0                        3.0
# 2023-09-29                          9.9                        3.0
# 2023-09-30                         10.0                        2.0
# 2023-01-10                          9.6                        2.0
#
# [274 rows x 5 columns]

# %%
for x in core_weather.index:
  if core_weather.loc[x, "Temp_rata-rata"] == 0.0:
    core_weather.drop(x, inplace=True)

# %%
for x in core_weather.index:
  if core_weather.loc[x, "Curah_hujan"] == 0.0:
    core_weather.drop(x, inplace=True)

# %%
for x in core_weather.index:
  if core_weather.loc[x, "Lamanya_penyinaran_matahari"] == 0.0:
    core_weather.drop(x, inplace=True)

# %%
for x in core_weather.index:
  if core_weather.loc[x, "Kecepatan_angin_rata-rata"] == 0.0:
    core_weather.drop(x, inplace=True)

# %%
core_weather
# Out:
#             Temp_rata-rata  Kelembapan_rata-rata  Curah_hujan  \
# Tanggal
# 2023-02-28            89.0                  89.0          1.7
# 2023-02-04            86.0                  86.0         11.7
# 2023-04-13            80.0                  80.0          7.0
# 2023-04-27            85.0                  85.0          6.0
# 2023-04-28            94.0                  94.0         30.5
# 2023-10-05            84.0                  84.0          0.5
# 2023-05-13            87.0                  87.0          0.4
# 2023-05-14            77.0                  77.0         25.5
# 2023-06-06            91.0                  91.0         12.5
# 2023-07-06            83.0                  83.0         17.5
# 2023-08-06            82.0                  82.0         13.0
# 2023-06-13            85.0                  85.0          7.5
# 2023-06-14            89.0                  89.0         63.0
# 2023-06-16            97.0                  97.0         49.0
# 2023-06-19            89.0                  89.0          3.7
# 2023-06-22            80.0                  80.0          8.7
# 2023-06-26            85.0                  85.0       8888.0
# 2023-06-28            80.0                  80.0         33.9
# 2023-07-25            81.0                  81.0       8888.0
# 2023-08-29            76.0                  76.0       8888.0
# 2023-09-18            76.0                  76.0       8888.0
# 2023-09-20            78.0                  78.0         28.9
# 2023-09-22            76.0                  76.0          1.5
#
#             Lamanya_penyinaran_matahari  Kecepatan_angin_rata-rata
# Tanggal
# 2023-02-28                          0.6                        3.0
# 2023-02-04                          0.6                        2.0
# 2023-04-13                          5.9                        4.0
# 2023-04-27                          3.5                        1.0
# 2023-04-28                          2.7                        1.0
# 2023-10-05                          3.9                        2.0
# 2023-05-13                          4.5                        2.0
# 2023-05-14                          4.0                        1.0
# 2023-06-06                          2.8                        2.0
# 2023-07-06                          0.5                        1.0
# 2023-08-06                          1.6                        2.0
# 2023-06-13                          0.1                        2.0
# 2023-06-14                          1.0                        2.0
# 2023-06-16                          5.1                        1.0
# 2023-06-19                          0.8                        2.0
# 2023-06-22                          4.0                        1.0
# 2023-06-26                          2.6                        1.0
# 2023-06-28                          5.5                        2.0
# 2023-07-25                          3.5                        1.0
# 2023-08-29                          1.0                        1.0
# 2023-09-18                          6.0                        2.0
# 2023-09-20                          0.9                        2.0
# 2023-09-22                          7.5                        2.0

# %%
core_weather.dtypes
# Out:
# Temp_rata-rata                 float64
# Kelembapan_rata-rata           float64
# Curah_hujan                    float64
# Lamanya_penyinaran_matahari    float64
# Kecepatan_angin_rata-rata      float64
# dtype: object

# %%
core_weather.index
# Out:
# DatetimeIndex(['2023-02-28', '2023-02-04', '2023-04-13', '2023-04-27',
#                '2023-04-28', '2023-10-05', '2023-05-13', '2023-05-14',
#                '2023-06-06', '2023-07-06', '2023-08-06', '2023-06-13',
#                '2023-06-14', '2023-06-16', '2023-06-19', '2023-06-22',
#                '2023-06-26', '2023-06-28', '2023-07-25', '2023-08-29',
#                '2023-09-18', '2023-09-20', '2023-09-22'],
#               dtype='datetime64[ns]', name='Tanggal', freq=None)

# %%
core_weather.index = pd.to_datetime(core_weather.index)

# %%
core_weather.index
# Out:
# DatetimeIndex(['2023-02-28', '2023-02-04', '2023-04-13', '2023-04-27',
#                '2023-04-28', '2023-10-05', '2023-05-13', '2023-05-14',
#                '2023-06-06', '2023-07-06', '2023-08-06', '2023-06-13',
#                '2023-06-14', '2023-06-16', '2023-06-19', '2023-06-22',
#                '2023-06-26', '2023-06-28', '2023-07-25', '2023-08-29',
#                '2023-09-18', '2023-09-20', '2023-09-22'],
#               dtype='datetime64[ns]', name='Tanggal', freq=None)

# %%
core_weather.apply(lambda x:(x==8888).sum())
# Out:
# Temp_rata-rata                 0
# Kelembapan_rata-rata           0
# Curah_hujan                    4
# Lamanya_penyinaran_matahari    0
# Kecepatan_angin_rata-rata      0
# dtype: int64

# %%
core_weather.dtypes
# Out:
# Temp_rata-rata                 float64
# Kelembapan_rata-rata           float64
# Curah_hujan                    float64
# Lamanya_penyinaran_matahari    float64
# Kecepatan_angin_rata-rata      float64
# dtype: object

# %%
core_weather
# Out:
#             Temp_rata-rata  Kelembapan_rata-rata  Curah_hujan  \
# Tanggal
# 2023-02-28            89.0                  89.0          1.7
# 2023-02-04            86.0                  86.0         11.7
# 2023-04-13            80.0                  80.0          7.0
# 2023-04-27            85.0                  85.0          6.0
# 2023-04-28            94.0                  94.0         30.5
# 2023-10-05            84.0                  84.0          0.5
# 2023-05-13            87.0                  87.0          0.4
# 2023-05-14            77.0                  77.0         25.5
# 2023-06-06            91.0                  91.0         12.5
# 2023-07-06            83.0                  83.0         17.5
# 2023-08-06            82.0                  82.0         13.0
# 2023-06-13            85.0                  85.0          7.5
# 2023-06-14            89.0                  89.0         63.0
# 2023-06-16            97.0                  97.0         49.0
# 2023-06-19            89.0                  89.0          3.7
# 2023-06-22            80.0                  80.0          8.7
# 2023-06-26            85.0                  85.0       8888.0
# 2023-06-28            80.0                  80.0         33.9
# 2023-07-25            81.0                  81.0       8888.0
# 2023-08-29            76.0                  76.0       8888.0
# 2023-09-18            76.0                  76.0       8888.0
# 2023-09-20            78.0                  78.0         28.9
# 2023-09-22            76.0                  76.0          1.5
#
#             Lamanya_penyinaran_matahari  Kecepatan_angin_rata-rata
# Tanggal
# 2023-02-28                          0.6                        3.0
# 2023-02-04                          0.6                        2.0
# 2023-04-13                          5.9                        4.0
# 2023-04-27                          3.5                        1.0
# 2023-04-28                          2.7                        1.0
# 2023-10-05                          3.9                        2.0
# 2023-05-13                          4.5                        2.0
# 2023-05-14                          4.0                        1.0
# 2023-06-06                          2.8                        2.0
# 2023-07-06                          0.5                        1.0
# 2023-08-06                          1.6                        2.0
# 2023-06-13                          0.1                        2.0
# 2023-06-14                          1.0                        2.0
# 2023-06-16                          5.1                        1.0
# 2023-06-19                          0.8                        2.0
# 2023-06-22                          4.0                        1.0
# 2023-06-26                          2.6                        1.0
# 2023-06-28                          5.5                        2.0
# 2023-07-25                          3.5                        1.0
# 2023-08-29                          1.0                        1.0
# 2023-09-18                          6.0                        2.0
# 2023-09-20                          0.9                        2.0
# 2023-09-22                          7.5                        2.0

# %%
for x in core_weather.index:
  if core_weather.loc[x, "Curah_hujan"] == 8888.0:
    core_weather.drop(x, inplace=True)

# %%
core_weather
# Out:
#             Temp_rata-rata  Kelembapan_rata-rata  Curah_hujan  \
# Tanggal
# 2023-02-28            89.0                  89.0          1.7
# 2023-02-04            86.0                  86.0         11.7
# 2023-04-13            80.0                  80.0          7.0
# 2023-04-27            85.0                  85.0          6.0
# 2023-04-28            94.0                  94.0         30.5
# 2023-10-05            84.0                  84.0          0.5
# 2023-05-13            87.0                  87.0          0.4
# 2023-05-14            77.0                  77.0         25.5
# 2023-06-06            91.0                  91.0         12.5
# 2023-07-06            83.0                  83.0         17.5
# 2023-08-06            82.0                  82.0         13.0
# 2023-06-13            85.0                  85.0          7.5
# 2023-06-14            89.0                  89.0         63.0
# 2023-06-16            97.0                  97.0         49.0
# 2023-06-19            89.0                  89.0          3.7
# 2023-06-22            80.0                  80.0          8.7
# 2023-06-28            80.0                  80.0         33.9
# 2023-09-20            78.0                  78.0         28.9
# 2023-09-22            76.0                  76.0          1.5
#
#             Lamanya_penyinaran_matahari  Kecepatan_angin_rata-rata
# Tanggal
# 2023-02-28                          0.6                        3.0
# 2023-02-04                          0.6                        2.0
# 2023-04-13                          5.9                        4.0
# 2023-04-27                          3.5                        1.0
# 2023-04-28                          2.7                        1.0
# 2023-10-05                          3.9                        2.0
# 2023-05-13                          4.5                        2.0
# 2023-05-14                          4.0                        1.0
# 2023-06-06                          2.8                        2.0
# 2023-07-06                          0.5                        1.0
# 2023-08-06                          1.6                        2.0
# 2023-06-13                          0.1                        2.0
# 2023-06-14                          1.0                        2.0
# 2023-06-16                          5.1                        1.0
# 2023-06-19                          0.8                        2.0
# 2023-06-22                          4.0                        1.0
# 2023-06-28                          5.5                        2.0
# 2023-09-20                          0.9                        2.0
# 2023-09-22                          7.5                        2.0
